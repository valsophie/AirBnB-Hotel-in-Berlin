# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
import requests
from lxml import html
import csv

# %%
url ="https://www.expedia.de/Hotel-Search?adults=2&destination=Berlin&endDate=2020-02-06&rooms=1&&startDate=2020-02-05"

# %%
driver = webdriver.Chrome()

# %%
with open('results.csv', 'w') as f:
    f.write("hotel_name, hotel_hood, price \n")
    
for i in range(0,16):
    url = "https://www.expedia.de/Hotel-Search?adults=2&destination=Berlin&endDate=2020-02-06&rooms=1&&startDate=2020-02-05&startingIndex=" + i*50)
    
# &startingIndex=800

# %%
driver.get(url)

# %%
page-num = 20

# %%
driver.get(url)

# %%
price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-101")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-102")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-103")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-104")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-105")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-106")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-107")>,
# ...

# %%
for i in range (len(hotel_name)): 
  print(hotel_name[i].text + " : " + 
          hood_name[i].text + " : " +
          price[i].text)

# %%
# Out:
# [([<selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-1")>,
#    <selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-2")>,
#    <selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-3")>,
#    <selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-4")>,
#    <selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-5")>,
#    <selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-6")>,
#    <selenium.webdriver.remote.webelement.WebElement (session="12138ee009f7d2ae9b34f61971f7ed43", element="0.603397997590406-7")>,
# ...
